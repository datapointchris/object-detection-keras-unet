# %%
from train import main_training_loop

# %%
main_training_loop(loop_epochs=2, augment_data=True, show_validation_plots=True)
# Out:
# Training Loop Epoch: 1 of 2
# BATCH NUMBER 1
# ...
# X_TRAIN
# Length: 14
# Shape: (14, 240, 240, 3)
# Size: 0.009 GB
# ...
#
# ...
# Y_TRAIN
# Length: 14
# Shape: (14, 240, 240, 1)
# Size: 0.003 GB
# ...
#
# ...
# X_VAL
# Length: 2
# Shape: (2, 240, 240, 3)
# Size: 0.001 GB
# ...
#
# ...
# Y_VAL
# Length: 2
# Shape: (2, 240, 240, 1)
# Size: 0.0 GB
# ...
#
# Creating New Model
# 2022-06-07 12:25:48.013045: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6591 - accuracy: 0.6223
# Epoch 1: val_loss improved from inf to 0.43744, saving model to models/unet_object_detection.hdf5
# ...
